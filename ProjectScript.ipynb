# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# navigate to the project folder
# %cd /content/gdrive/My Drive/
# %cd Project

# %%
# initialize a local git repo
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Project/.git/

# %%
# create git ignore file
# !touch .gitignore

# %%
# put the git.ipynb file in gitignore so they are not uploaded to the repo
# !echo git.ipynb>> .gitignore

# %%
# create remote repository
# !git remote add origin https://USERNAME:TOKEN@github.com/USERNAME/REPOSITORY-NAME.git

# %%
# configure user
# !git config --global user.email '{EMAIL}'
# !git config --global user.name '{USERNAME}'

# %%
# stage and commit all files in the project folder
# !git add .
# !git commit -m 'First commit'

# %%
# push file
# !git push origin master
